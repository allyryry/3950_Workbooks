# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras.datasets import fashion_mnist, cifar10
from keras.layers import Dense, Flatten, Normalization, Dropout, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomZoom, BatchNormalization, Activation, InputLayer
from keras.models import Sequential
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras import utils
import os
from keras.preprocessing.image import ImageDataGenerator

import matplotlib as mpl
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Tensorboard and Pretrained Models

# %%
# Load Some Data
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_test = np_utils.to_categorical(y_test)
y_train = np_utils.to_categorical(y_train)

# %% [markdown]
# ## Tensorboard
#
# Tensorboard is a tool from Keras that can monitor the results of a tensorflow model and display it in a nice Tableau-like dashboard view. We can enable tensorboard and add it to our modelling process to get a better view of progress and save on some of the custom charting functions.
#
# The first thing that we can use tensorboard for is to get a nice chart of our training progress.
#
# ### Create Model

# %%
# Set # of epochs
epochs = 10

# %%
def create_model():
  return tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
  ])

# %%
acc = keras.metrics.CategoricalAccuracy(name="accuracy")
pre = keras.metrics.Precision(name="precision")
rec = keras.metrics.Recall(name="recall")
metric_list = [acc, pre, rec]

# %% [markdown]
# #### Add Tensorboard Callback
#
# The tensorboard can be added to the model as it is being fit as a callback. The primary parameter that matters there is the log_dir, where we can setup the folder to put the logs that the visualizations are made from. The example I have here is from the tensorflow documentation, generating a new subfolder for each execution. Using this to log the tensorboard data is fine, there's no need to change it without reason.

# %% [markdown]
# ### Launch Tensorboard
#
# In recent versions of VS Code, whioch I assume all of you have, tensorboard can be used directly in a VS Code tab:
#
# ![VS Code Tensor](images/vscode_tensorboard.png "VS Code Tensor" )
#
# The command below launches tensorboard elsewhere, such as Google colab.
#
# Either way, the actual tensorboard feature works the same once launched. We can open it before or after we start training the model. If we open it before we can update it to watch training progress - something that may be usefull if you have models that can train for a very long time.

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# The logdir is wherever the logs are, this is specified in the callback setup.
# Out:
#       <iframe id="tensorboard-frame-fa885906a01b782" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-fa885906a01b782");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model = create_model()
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=metric_list)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(x=x_train, 
          y=y_train, 
          epochs=epochs, 
          validation_data=(x_test, y_test), 
          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 25s 12ms/step - loss: 0.2211 - accuracy: 0.9345 - precision: 0.9553 - recall: 0.9165 - val_loss: 0.1106 - val_accuracy: 0.9668 - val_precision: 0.9736 - val_recall: 0.9616
# Epoch 2/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0973 - accuracy: 0.9705 - precision: 0.9750 - recall: 0.9664 - val_loss: 0.0840 - val_accuracy: 0.9737 - val_precision: 0.9779 - val_recall: 0.9702
# Epoch 3/10
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0692 - accuracy: 0.9786 - precision: 0.9819 - recall: 0.9765 - val_loss: 0.0714 - val_accuracy: 0.9788 - val_precision: 0.9803 - val_recall: 0.9767
# Epoch 4/10
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0534 - accuracy: 0.9828 - precision: 0.9848 - recall: 0.9812 - val_loss: 0.0657 - val_accuracy: 0.9786 - val_precision: 0.9808 - val_recall: 0.9771
# Epoch 5/10
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0417 - accuracy: 0.9866 - precision: 0.9879 - recall: 0.9855 - val_loss: 0.0669 - val_accuracy: 0.9803 - val_precision: 0.9824 - val_recall: 0.9792
# Epoch 6/10
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0358 - accuracy: 0.9874 - precision: 0.9886 - recall: 0.9867 - val_loss: 0.0707 - val_accuracy: 0.9799 - val_precision: 0.9809 - val_recall: 0.9792
# Epoch 7/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0298 - accuracy: 0.9904 - precision: 0.9911 - recall: 0.9896 - val_loss: 0.0742 - val_accuracy: 0.9801 - val_precision: 0.9814 - val_recall: 0.9789
# Epoch 8/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0270 - accuracy: 0.9910 - precision: 0.9917 - recall: 0.9903 - val_loss: 0.0776 - val_accuracy: 0.9813 - val_precision: 0.9820 - val_recall: 0.9806
# Epoch 9/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0258 - accuracy: 0.9913 - precision: 0.9919 - recall: 0.9908 - val_loss: 0.0753 - val_accuracy: 0.9814 - val_precision: 0.9828 - val_recall: 0.9808
# Epoch 10/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0216 - accuracy: 0.9929 - precision: 0.9932 - recall: 0.9926 - val_loss: 0.0762 - val_accuracy: 0.9814 - val_precision: 0.9826 - val_recall: 0.9811

# %% [markdown]
# ### Tensorboard Contents
#
# The first page of the tensorboard page gives us a nice pretty view of our training progress - this part should be quite straightforward. The board will capture whatever executions are in that log file, we can filter them on the side to see what we are currently working on, or use different log locations to keep things separate.
#
# Like the text results, we get whichever metrics were specified when setting up the model.
#
# #### Tensorboard Images
#
# We can also use the tensorboard to visualize other stuff. For example we can load up some images from our dataset.

# %%
# Sets up a timestamped log directory.

logdir = "logs/train_data/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# Creates a file writer for the log directory.
file_writer = tf.summary.create_file_writer(logdir)

# %%
with file_writer.as_default():
    # Don't forget to reshape.
    images = np.reshape(x_train[0:25], (-1, 28, 28, 1))
    tf.summary.image("25 training data examples", images, max_outputs=25, step=0)

# %% [markdown]
# ## Using Pretrained Models
#
# As we've seen lately, training neural networks can take a really long time. Highly accurate models such as the ones that are used for image recognition in a self driving cars can take multiple computers days or weeks to train. With one laptop we don't really have the ability to get anywhere close to that. Is there any hope of getting anywhere near that accurate?
#
# We can use models that have been trained on large datasets and adapt them to our purposes. By doing this we can benefit from all of that other learning that is embedded into a model without going through a training process that would be impossible with our limited resources.
#
# We will look at using a pretrained model here, and at making modifications to it next time.
#
# #### Functional Models
#
# I have lied to you, I forgot that the pretrained models are not sequntial ones (generally, not as a rule), so some of the syntax here is for functional models. It leads to us using some slightly unfamiliar syntax.

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')

train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 32
IMG_SIZE = (160, 160)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 2s 0us/step
# 68616192/68606236 [==============================] - 2s 0us/step
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# ### Download Model
#
# There are several models that are pretrained and available to us to use. VGG16 is one developed to do image recognition, the name stands for "Visual Geometry Group" - a group of researchers at the University of Oxford who developed it, and ‘16’ implies that this architecture has 16 layers. The model got ~93% on the ImageNet test that we mentioned a couple of weeks ago.
#
# ![VGG16](images/vgg16.png "VGG16" )

# %%
# Load Model
from keras.applications.vgg16 import VGG16
from keras.layers import Input
from keras.models import Model

input_tensor = Input(shape=(160, 160, 3))
vgg = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)

for layer in vgg.layers:
    layer.trainable = False

x = Flatten()(vgg.output)
prediction = Dense(1, activation='sigmoid')(x)

model = Model(inputs=vgg.input, outputs=prediction)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step
# 58900480/58889256 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 160, 160, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 160, 160, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 80, 80, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 80, 80, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 80, 80, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 40, 40, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 40, 40, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 40, 40, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 40, 40, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 20, 20, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 20, 20, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 20, 20, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 10, 10, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_2 (Dense)             (None, 1)                 12801
#
# =================================================================
# Total params: 14,727,489
# Trainable params: 12,801
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=metric_list)

log_dir = "logs/fit/VGG" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(train_dataset, 
          epochs=epochs, 
          validation_data=validation_dataset, 
          callbacks=[tensorboard_callback])
          
model.evaluate(validation_dataset)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 376s 6s/step - loss: 0.0000e+00 - accuracy: 0.9845 - precision: 0.9820 - recall: 0.8920 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/10
# 63/63 [==============================] - 332s 5s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/10
# 63/63 [==============================] - 370s 6s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/10
# 63/63 [==============================] - 351s 6s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/10
# 63/63 [==============================] - 353s 6s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/10
# 63/63 [==============================] - 328s 5s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/10
# 63/63 [==============================] - 2119s 34s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/10
# 63/63 [==============================] - 260s 4s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/10
# 63/63 [==============================] - 251s 4s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/10
# 63/63 [==============================] - 261s 4s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# 32/32 [==============================] - 86s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00
# [0.0, 1.0, 0.0, 0.0]

# %%
model.evaluate(validation_dataset)
# Out:
# 32/32 [==============================] - 93s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00
# [0.0, 1.0, 0.0, 0.0]

# %% [markdown]
# ## More Complex Data
#
# We can use the rose data for a more complex dataset and a more interesting example in terms of accuracy.

# %%
import pathlib
import PIL 

dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                   fname='flower_photos',
                                   untar=True)
data_dir = pathlib.Path(data_dir)

#Flowers
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 4s 0us/step
# 228827136/228813984 [==============================] - 4s 0us/step
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
# Add VGG Model

# %%
# Compile and Train

# %% [markdown]
# ## Hyperparameter Tuning
#
# We can also utilize the tensorboard display to give us a view of hyperparameter tuning. This requires more work than a simple grid search, but the results are pretty similar. Below is an example adapted from the tensorflow docs.
#
# We'll do this with a simple model - a dense layer, a dropout, and the output, more complex ones are the same in their setup:
# <ol>
# <li> HP_NUM_UNITS - test a different number of units between 16 and 64.
# <li> HP_DROPOUT - the proportion of dropouts in the dropout.
# <li> HP_OPTIMIZER - we can try some different optimizers.
# </ol>

# %%
# Load some data
from tensorboard.plugins.hparams import api as hp
fashion_mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 1us/step
# 40960/29515 [=========================================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# #### Setup Parameters
#
# We can define the parameters we want to grid search here. Each one is one of these hParam objects - we assign it a name and a range of values to use, here we have a numerical and a discreet example. We list those variables in the hparams argument.
#
# This is very similar to the idea of setting different values in a gridsearch, just with slightly different syntax.

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([16, 32, 48, 64]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.1, 0.4))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd', "rmsprop"]))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_OPTIMIZER],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %% [markdown]
# #### Build Test Models
#
# We can create our models inside of some helper functions - each one will run a model with certain HPs and return the accuracy, or whichever other metric we define.
#
# Note the key change - the variables that we are changing are replaced with the matching hparams item.

# %%
def train_test_model(hparams):
  model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(hparams[HP_NUM_UNITS], activation=tf.nn.relu),
    tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax),
  ])
  model.compile(
      optimizer=hparams[HP_OPTIMIZER],
      loss='sparse_categorical_crossentropy',
      metrics=['accuracy'],
  )

  model.fit(x_train, y_train, epochs=10) 
  _, accuracy = model.evaluate(x_test, y_test)
  return accuracy

# %%
def run(run_dir, hparams):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = train_test_model(hparams)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %% [markdown]
# #### Perfrom the GridSearch
#
# We have to write the gridsearch manually, but we can copy this basic setup as a template and modify it. Once complete, load tensorboard and go to the HPARAMS section to visualize.
#
# The parallel coordinates view allows us to do a quick exploration of the best HPs.

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
  for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
    for optimizer in HP_OPTIMIZER.domain.values:
      hparams = {
          HP_NUM_UNITS: num_units,
          HP_DROPOUT: dropout_rate,
          HP_OPTIMIZER: optimizer,
      }
      run_name = "run-%d" % session_num
      print('--- Starting trial: %s' % run_name)
      print({h.name: hparams[h] for h in hparams})
      run('logs/hparam_tuning/' + run_name, hparams)
      session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 16, 'dropout': 0.1, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.6853 - accuracy: 0.7639
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4926 - accuracy: 0.8253
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4573 - accuracy: 0.8358
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4362 - accuracy: 0.8431
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4255 - accuracy: 0.8468
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4122 - accuracy: 0.8511
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4070 - accuracy: 0.8515
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3996 - accuracy: 0.8538
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3963 - accuracy: 0.8543
# Epoch 10/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3896 - accuracy: 0.8570
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4020 - accuracy: 0.8529
# --- Starting trial: run-1
# {'num_units': 16, 'dropout': 0.1, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6966 - accuracy: 0.7564
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5018 - accuracy: 0.8236
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4730 - accuracy: 0.8307
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4570 - accuracy: 0.8378
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4507 - accuracy: 0.8410
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4423 - accuracy: 0.8456
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4379 - accuracy: 0.8461
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4359 - accuracy: 0.8471
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4330 - accuracy: 0.8500
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4300 - accuracy: 0.8483
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4331 - accuracy: 0.8544
# --- Starting trial: run-2
# {'num_units': 16, 'dropout': 0.1, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.0934 - accuracy: 0.6237
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7204 - accuracy: 0.7470
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6345 - accuracy: 0.7816
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5894 - accuracy: 0.7973
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5625 - accuracy: 0.8060
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5449 - accuracy: 0.8106
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5329 - accuracy: 0.8134
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5205 - accuracy: 0.8159
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5111 - accuracy: 0.8182
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5009 - accuracy: 0.8222
# 313/313 [==============================] - 3s 2ms/step - loss: 0.4587 - accuracy: 0.8352
# --- Starting trial: run-3
# {'num_units': 16, 'dropout': 0.4, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.0109 - accuracy: 0.6326
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7648 - accuracy: 0.7142
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7253 - accuracy: 0.7284
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7007 - accuracy: 0.7352
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6926 - accuracy: 0.7362
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6772 - accuracy: 0.7438
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6687 - accuracy: 0.7458
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6708 - accuracy: 0.7461
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6666 - accuracy: 0.7455
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6639 - accuracy: 0.7493
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4740 - accuracy: 0.8396
# --- Starting trial: run-4
# {'num_units': 16, 'dropout': 0.4, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.0296 - accuracy: 0.6108
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8450 - accuracy: 0.6798
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8120 - accuracy: 0.6974
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7954 - accuracy: 0.7056
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.7951 - accuracy: 0.7065
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7809 - accuracy: 0.7147
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7835 - accuracy: 0.7162
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7823 - accuracy: 0.7153
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7836 - accuracy: 0.7179
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7698 - accuracy: 0.7214
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5721 - accuracy: 0.8054
# --- Starting trial: run-5
# {'num_units': 16, 'dropout': 0.4, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.3129 - accuracy: 0.5348
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9437 - accuracy: 0.6568
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8506 - accuracy: 0.6911
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.8078 - accuracy: 0.7076
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7794 - accuracy: 0.7148
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7583 - accuracy: 0.7228
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.7500 - accuracy: 0.7255
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7367 - accuracy: 0.7312
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7278 - accuracy: 0.7348
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7227 - accuracy: 0.7370
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5125 - accuracy: 0.8164
# --- Starting trial: run-6
# {'num_units': 32, 'dropout': 0.1, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6229 - accuracy: 0.7838
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4473 - accuracy: 0.8412
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4111 - accuracy: 0.8518
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3900 - accuracy: 0.8590
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3757 - accuracy: 0.8630
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3661 - accuracy: 0.8659
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3562 - accuracy: 0.8683
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3467 - accuracy: 0.8722
# Epoch 9/10
# 1875/1875 [==============================] - 156s 83ms/step - loss: 0.3451 - accuracy: 0.8737
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3374 - accuracy: 0.8758
# 313/313 [==============================] - 2s 3ms/step - loss: 0.3621 - accuracy: 0.8692
# --- Starting trial: run-7
# {'num_units': 32, 'dropout': 0.1, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.5964 - accuracy: 0.7917
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4438 - accuracy: 0.8433
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4179 - accuracy: 0.8522
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4041 - accuracy: 0.8583
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3949 - accuracy: 0.8623
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3881 - accuracy: 0.8653
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3863 - accuracy: 0.8664
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3816 - accuracy: 0.8677
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3779 - accuracy: 0.8675
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3755 - accuracy: 0.8705
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4196 - accuracy: 0.8631
# --- Starting trial: run-8
# {'num_units': 32, 'dropout': 0.1, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.9070 - accuracy: 0.6949
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6013 - accuracy: 0.7972
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5373 - accuracy: 0.8163
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5029 - accuracy: 0.8267
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4808 - accuracy: 0.8332
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4625 - accuracy: 0.8391
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4503 - accuracy: 0.8431
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4406 - accuracy: 0.8458
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4313 - accuracy: 0.8492
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4218 - accuracy: 0.8526
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4208 - accuracy: 0.8498
# --- Starting trial: run-9
# {'num_units': 32, 'dropout': 0.4, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7785 - accuracy: 0.7244
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5779 - accuracy: 0.7924
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5441 - accuracy: 0.8037
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5267 - accuracy: 0.8096
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5143 - accuracy: 0.8134
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5021 - accuracy: 0.8196
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4923 - accuracy: 0.8217
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4876 - accuracy: 0.8225
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4841 - accuracy: 0.8223
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4758 - accuracy: 0.8258
# 313/313 [==============================] - 4s 2ms/step - loss: 0.4086 - accuracy: 0.8494
# --- Starting trial: run-10
# {'num_units': 32, 'dropout': 0.4, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.7435 - accuracy: 0.7420
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5670 - accuracy: 0.8015
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5457 - accuracy: 0.8086
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5366 - accuracy: 0.8130
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5278 - accuracy: 0.8155
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5263 - accuracy: 0.8177
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5238 - accuracy: 0.8205
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5245 - accuracy: 0.8208
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5299 - accuracy: 0.8210
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5288 - accuracy: 0.8215
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4501 - accuracy: 0.8474
# --- Starting trial: run-11
# {'num_units': 32, 'dropout': 0.4, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 1.1346 - accuracy: 0.6099
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7747 - accuracy: 0.7330
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6981 - accuracy: 0.7605
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6566 - accuracy: 0.7712
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6327 - accuracy: 0.7787
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6144 - accuracy: 0.7840
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5997 - accuracy: 0.7891
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5873 - accuracy: 0.7925
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5815 - accuracy: 0.7954
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5734 - accuracy: 0.7984
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4607 - accuracy: 0.8348
# --- Starting trial: run-12
# {'num_units': 48, 'dropout': 0.1, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5728 - accuracy: 0.7999
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4191 - accuracy: 0.8512
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3871 - accuracy: 0.8614
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3649 - accuracy: 0.8671
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3507 - accuracy: 0.8717
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3372 - accuracy: 0.8773
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3269 - accuracy: 0.8805
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3193 - accuracy: 0.8815
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3130 - accuracy: 0.8842
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3050 - accuracy: 0.8863
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3644 - accuracy: 0.8728
# --- Starting trial: run-13
# {'num_units': 48, 'dropout': 0.1, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5539 - accuracy: 0.8045
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4142 - accuracy: 0.8519
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3857 - accuracy: 0.8628
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3705 - accuracy: 0.8709
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3600 - accuracy: 0.8733
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3521 - accuracy: 0.8752
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3501 - accuracy: 0.8788
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3468 - accuracy: 0.8806
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3453 - accuracy: 0.8818
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3382 - accuracy: 0.8848
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4206 - accuracy: 0.8730
# --- Starting trial: run-14
# {'num_units': 48, 'dropout': 0.1, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8584 - accuracy: 0.7056
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5807 - accuracy: 0.8041
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5181 - accuracy: 0.8225
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4816 - accuracy: 0.8339
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4581 - accuracy: 0.8407
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4401 - accuracy: 0.8457
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4281 - accuracy: 0.8504
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4182 - accuracy: 0.8525
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4077 - accuracy: 0.8575
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3998 - accuracy: 0.8582
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4144 - accuracy: 0.8537
# --- Starting trial: run-15
# {'num_units': 48, 'dropout': 0.4, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6997 - accuracy: 0.7549
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5206 - accuracy: 0.8147
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4878 - accuracy: 0.8248
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4675 - accuracy: 0.8312
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4517 - accuracy: 0.8356
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4409 - accuracy: 0.8397
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4339 - accuracy: 0.8417
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4287 - accuracy: 0.8432
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4221 - accuracy: 0.8474
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4172 - accuracy: 0.8467
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3870 - accuracy: 0.8573
# --- Starting trial: run-16
# {'num_units': 48, 'dropout': 0.4, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6994 - accuracy: 0.7566
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5330 - accuracy: 0.8142
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5088 - accuracy: 0.8239
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5012 - accuracy: 0.8274
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4945 - accuracy: 0.8323
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4904 - accuracy: 0.8325
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4878 - accuracy: 0.8338
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4918 - accuracy: 0.8357
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4895 - accuracy: 0.8363
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4960 - accuracy: 0.8364
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4659 - accuracy: 0.8497
# --- Starting trial: run-17
# {'num_units': 48, 'dropout': 0.4, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 1.0819 - accuracy: 0.6241
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7375 - accuracy: 0.7442
# Epoch 3/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6530 - accuracy: 0.7739
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6071 - accuracy: 0.7904
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5793 - accuracy: 0.8023
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5564 - accuracy: 0.8078
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5439 - accuracy: 0.8129
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5288 - accuracy: 0.8179
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5184 - accuracy: 0.8200
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5114 - accuracy: 0.8222
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4403 - accuracy: 0.8439
# --- Starting trial: run-18
# {'num_units': 64, 'dropout': 0.1, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5484 - accuracy: 0.8080
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4067 - accuracy: 0.8534
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3724 - accuracy: 0.8656
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3520 - accuracy: 0.8718
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3356 - accuracy: 0.8773
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3200 - accuracy: 0.8824
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3115 - accuracy: 0.8838
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3001 - accuracy: 0.8904
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2922 - accuracy: 0.8926
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2870 - accuracy: 0.8927
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3489 - accuracy: 0.8736
# --- Starting trial: run-19
# {'num_units': 64, 'dropout': 0.1, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.5415 - accuracy: 0.8119
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4108 - accuracy: 0.8532
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3844 - accuracy: 0.8645
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3685 - accuracy: 0.8714
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3580 - accuracy: 0.8742
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3498 - accuracy: 0.8779
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3461 - accuracy: 0.8803
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3417 - accuracy: 0.8831
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3338 - accuracy: 0.8861
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3338 - accuracy: 0.8864
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4110 - accuracy: 0.8687
# --- Starting trial: run-20
# {'num_units': 64, 'dropout': 0.1, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7982 - accuracy: 0.7359
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5575 - accuracy: 0.8102
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5019 - accuracy: 0.8275
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4700 - accuracy: 0.8382
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4496 - accuracy: 0.8441
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4327 - accuracy: 0.8493
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4191 - accuracy: 0.8527
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4095 - accuracy: 0.8561
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4002 - accuracy: 0.8602
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3902 - accuracy: 0.8628
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4086 - accuracy: 0.8557
# --- Starting trial: run-21
# {'num_units': 64, 'dropout': 0.4, 'optimizer': 'adam'}
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6481 - accuracy: 0.7744
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4830 - accuracy: 0.8265
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4534 - accuracy: 0.8354
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4337 - accuracy: 0.8421
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4191 - accuracy: 0.8473
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4091 - accuracy: 0.8507
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3992 - accuracy: 0.8556
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3936 - accuracy: 0.8554
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3845 - accuracy: 0.8577
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3789 - accuracy: 0.8597
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3771 - accuracy: 0.8644
# --- Starting trial: run-22
# {'num_units': 64, 'dropout': 0.4, 'optimizer': 'rmsprop'}
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6417 - accuracy: 0.7762
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4951 - accuracy: 0.8261
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4740 - accuracy: 0.8379
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4635 - accuracy: 0.8422
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4656 - accuracy: 0.8447
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4599 - accuracy: 0.8480
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4610 - accuracy: 0.8495
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4615 - accuracy: 0.8500
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4620 - accuracy: 0.8497
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4639 - accuracy: 0.8513
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4848 - accuracy: 0.8591
# --- Starting trial: run-23
# {'num_units': 64, 'dropout': 0.4, 'optimizer': 'sgd'}
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.9311 - accuracy: 0.6859
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6391 - accuracy: 0.7853
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5686 - accuracy: 0.8043
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5326 - accuracy: 0.8163
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5098 - accuracy: 0.8222
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4885 - accuracy: 0.8284
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4784 - accuracy: 0.8328
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4680 - accuracy: 0.8360
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4589 - accuracy: 0.8391
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4494 - accuracy: 0.8432
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4157 - accuracy: 0.8504
